# %%
import numpy as np 
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
import ModelLib

# %%
model = ModelLib.SIRModels()
# Out:
# /Users/simonblaue/Desktop/Epidemics_SRI_model/ModelLib.py:21: RuntimeWarning: overflow encountered in exp
#   self.P = lambda H: self.p_base+(1-self.p_base)/self.p_cap*self.epsilon*np.log(1+np.exp(1/self.epsilon*(self.p_cap-H)))

# %%
model.s = 0
model.T = 45
model.dI_thresh= 0.001
model.d_pcap_min= model.p_cap/5
model.Ti = 2
ModelLib.plots.PlotSRITime(model.AdaptivePIncrement, y0=[0.99,0.01,0,0,0,0,0], t_range=[0,2000], plot_range=range(0,360))
ModelLib.plots.PlotSRITime(model.SeasonalyIncrement, y0=[0.99,0.01,0,0,0], t_range=[0,2000], plot_range=range(0,360))
# Out:
# /Users/simonblaue/Desktop/Epidemics_SRI_model/ModelLib.py:130: RuntimeWarning: overflow encountered in exp
#   return (1-self.p_base)/(1+np.exp(epsilon*(1/(pcap2-H)+1/(pcap1-H))))+self.p_base

# %%
ModelLib.plots.PlotBifurcation(model, model.AdaptivePIncrement)
# Out:
# /Users/simonblaue/Desktop/Epidemics_SRI_model/ModelLib.py:130: RuntimeWarning: overflow encountered in exp
#   return (1-self.p_base)/(1+np.exp(epsilon*(1/(pcap2-H)+1/(pcap1-H))))+self.p_base
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%

# %%
ModelLib.plots.PlotBifurcation(model, model.SeasonalyIncrement)
# Out:
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
