# %%
import numpy as np 
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
import ModelLib

# %%
model = ModelLib.SIRModels()
# Out:
# /Users/simonblaue/Desktop/Epidemics_SRI_model/ModelLib.py:21: RuntimeWarning: overflow encountered in exp
#   self.P = lambda H: self.p_base+(1-self.p_base)/self.p_cap*self.epsilon*np.log(1+np.exp(1/self.epsilon*(self.p_cap-H)))

# %%
dict = solve_ivp(model.AdaptivePIncrement, [0,1000], [0.999,0.001,0,0,0,0, 0], max_step=10)

# %%
model.s = 0

model.dI_thresh= 0.001
ModelLib.plots.PlotSRITime(model.SeasonalyIncrement, y0=[0.999,0.001,0,0,0])

# %%
#ModelLib.plots.PlotBifurcation(model, model.AdaptivePIncrement)
