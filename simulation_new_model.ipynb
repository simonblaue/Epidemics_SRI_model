# %%
import numpy as np 
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
import ModelLib

# %%
model = ModelLib.SIRModels()
# Out:
# /Users/simonblaue/Desktop/Epidemics_SRI_model/ModelLib.py:22: RuntimeWarning: overflow encountered in exp
#   self.P = lambda H: self.p_base+(1-self.p_base)/self.p_cap*self.epsilon*np.log(1+np.exp(1/self.epsilon*(self.p_cap-H)))

# %%
model.s = 0.3
model.T = 60
model.Ti = 1
model.dI_thresh= 0.0001
model.p_cap = 0.05 # standard wert
# model.p_cap = 0.1
model.d_pcap_min= model.p_cap/100
ModelLib.plots.PlotPH(model,model.AdaptivePIncrement, y0=[0.99,0.01,0,0,0,0,0], T_min = 0, T_max = 2000)
ModelLib.plots.PlotPH(model,model.SeasonalyIncrement, y0=[0.99,0.01,0,0,0], T_min = 0, T_max = 2000)
# Out:
# /Users/simonblaue/Desktop/Epidemics_SRI_model/ModelLib.py:227: RuntimeWarning: overflow encountered in exp
#   return (1-self.p_base)/(1+np.exp(epsilon*((1/(pcap2-H)+1/(pcap1-H)))))+self.p_base
# (array([0.0000e+00, 5.0000e-01, 1.0000e+00, ..., 1.9985e+03, 1.9990e+03,
#         1.9995e+03]),
#  array([[9.90000000e-01, 9.86311878e-01, 9.81502358e-01, ...,
#          4.86349609e-01, 4.80653017e-01, 4.75180778e-01],
#         [1.00000000e-02, 1.31150625e-02, 1.71764155e-02, ...,
#          1.43935448e-01, 1.44287527e-01, 1.44429597e-01],
#         [0.00000000e+00, 5.73059501e-04, 1.32122626e-03, ...,
#          3.69714943e-01, 3.75059457e-01, 3.80389625e-01],
#         [0.00000000e+00, 1.89960653e-04, 4.35774396e-04, ...,
#          5.63429715e-02, 5.77939560e-02, 5.92250342e-02],
#         [0.00000000e+00, 1.50737153e-06, 6.57165523e-06, ...,
#          2.15951358e-02, 2.21815169e-02, 2.27820280e-02]]))

# %%
t_end = 2000
ModelLib.plots.PlotSRITime(model, model.AdaptivePIncrement, y0=[0.99,0.01,0,0,0,0,0], T_min=0, T_max=1000 )
ModelLib.plots.PlotSRITime(model, model.SeasonalyIncrement, y0=[0.99,0.01,0,0,0], T_min=0, T_max=1000 )
ModelLib.plots.PlotSRITime(model, model.DifferentPIncrement, y0=[0.99,0.01,0,0,0], T_min=0, T_max=1000 )
# Out:
# /Users/simonblaue/Desktop/Epidemics_SRI_model/ModelLib.py:227: RuntimeWarning: overflow encountered in exp
#   return (1-self.p_base)/(1+np.exp(epsilon*((1/(pcap2-H)+1/(pcap1-H)))))+self.p_base
# /Users/simonblaue/Desktop/Epidemics_SRI_model/ModelLib.py:227: RuntimeWarning: overflow encountered in exp
#   return (1-self.p_base)/(1+np.exp(epsilon*((1/(pcap2-H)+1/(pcap1-H)))))+self.p_base
# (array([0.00000000e+00, 1.13944699e-01, 1.11394470e+00, ...,
#         9.98113945e+02, 9.99113945e+02, 1.00000000e+03]),
#  array([[9.90000000e-01, 9.89243948e-01, 9.80216739e-01, ...,
#          3.84124951e-01, 3.89764393e-01, 3.94740725e-01],
#         [1.00000000e-02, 1.06385725e-02, 1.82618011e-02, ...,
#          1.69112415e-02, 1.56144279e-02, 1.45535276e-02],
#         [0.00000000e+00, 1.17479562e-04, 1.52146030e-03, ...,
#          5.98963808e-01, 5.94621179e-01, 5.90705747e-01],
#         [0.00000000e+00, 3.91083888e-05, 5.01280167e-04, ...,
# ...

# %%
# ModelLib.plots.PlotBifurcation(model, model.AdaptivePIncrement)

# %%
# ModelLib.plots.PlotBifurcation(model, model.SeasonalyIncrement)

# %%
model = ModelLib.SIRModels(s=0, p_cap=0.07, dI_thresh=0.05, reductionfactor=1/10)
# Out:
# /Users/simonblaue/Desktop/Epidemics_SRI_model/ModelLib.py:22: RuntimeWarning: overflow encountered in exp
#   self.P = lambda H: self.p_base+(1-self.p_base)/self.p_cap*self.epsilon*np.log(1+np.exp(1/self.epsilon*(self.p_cap-H)))
